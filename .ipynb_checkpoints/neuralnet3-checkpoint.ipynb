# %% [markdown]
# # =====================================================
# # Rede Neural com 3 camada
#
# # Rodrigo/Jônatas, não vale para o exercício, é apenas um TESTE.
#
# # =====================================================

# %%
# Configuração inicial

import numpy as np
import matplotlib.pyplot as plt

from rncvc.classifiers.neural_net3L import NeuralNet3L

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Permite a recarga automática de arquivos python importados
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
  """ retorna erro relativo """
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %% [markdown]
# Implemente a rede neural na classe `NeuralNet` no arquivo `rncvc/classifiers/neural_net.py`. Os parâmetros (pesos) da rede são armazenados na variável (dicionário) `self.params`, onde as chaves são os nomes (string) das camadas e os valores são numpy arrays com os pesos. A seguir, inicializamos dados sintéticos e uma rede simplificada para guiar o procedimento de desenvolvimento.

# %%
# Criação de um modelo e um conjunto de dados para alguns testes.
# Definimos um seed para que seja possivel a conferência dos resultados.

input_size = 4
hidden_size = 10
hidden_size2 = 15
num_classes = 3
num_inputs = 5

def init_toy_model():
    np.random.seed(0)
    return NeuralNet3L(input_size, hidden_size, hidden_size2, num_classes, std=1e-1)

def init_toy_data():
    np.random.seed(1)
    X = 10 * np.random.randn(num_inputs, input_size)
    y = np.array([0, 1, 2, 2, 1])
    return X, y

net = init_toy_model()
X, y = init_toy_data()
# Out:
# W1: (4L, 10L)
# b1: (10L,)
# W2: (10L, 15L)
# b2: (15L,)
# W3: (15L, 3L)
# b3: (3L,)

# %% [markdown]
# # Forward: calcule valores de predição para as classes
# A função `NeuralNet.loss` utiliza os dados e os parâmetros para calcular as predições para cada classe. Além disso, são calculados: o valor da função de custo e os gradientes dos parâmetros.
#
# Implemente a primeira parte, que faz a predição das classes.

# %%
scores = net.loss(X, reg=0.1)
print 'Suas predicoes:'
print scores.shape
print scores
# Out:
# Suas predicoes:
# (5L, 3L)
# [[-0.12143288  0.13845538 -0.1111609 ]
#  [-0.36797031  0.28168056 -0.18445697]
#  [-0.44938763  0.23235063 -0.20434098]
#  [-0.16901828  0.12397267 -0.08396804]
#  [-0.00878972  0.00958007  0.01437574]]

# %% [markdown]
# # Forward: calcule a função de custo
#
# Na mesma função, implemente a segunda parte, calculando os valores da função de custo.

# %%
loss, _ = net.loss(X, y, reg=0.1)

print loss
# Out:
# 1.19699695429

# %% [markdown]
# # Backward
#
# Implemente o restante da função. Aqui os gradientes com respeito às variáveis `W1`, `b1`, `W2`, e `b2` devem ser calculados.
# Com uma implementação correta de todo o processo de backward você deve ser capaz de conferir utilizando o gradiente numérico.

# %%
from rncvc.gradient_check import eval_numerical_gradient

# Use o gradiente numérico para verificar sua implementação da etapa backward.
# Se sua implementação estiver correta, a diferença entre os gradientes será 
# inferior a 1e-8 para cada um das camadas de pesos: W1, W2, b1, b2.

loss, grads = net.loss(X, y, reg=0.1)

# as diferenças devem ser pequenas (<1e-8)
for param_name in grads:
    f = lambda W: net.loss(X, y, reg=0.1)[0]
    param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
    print '%s erro relativo max: %e' % (param_name, rel_error(param_grad_num, grads[param_name]))
# Out:
# b2 erro relativo max: 5.135895e-09
# W3 erro relativo max: 1.273393e-07
# b1 erro relativo max: 2.747558e-09
# W1 erro relativo max: 3.561318e-09
# b3 erro relativo max: 4.612931e-10
# W2 erro relativo max: 3.440708e-09

# %% [markdown]
# # Treinando a rede (modelo toy)
#
# Para treinar, utilize o SGD. Preencha os espaços em branco da função NeuralNet.train. Ainda, você precisa implementar a função NeuralNet.predict utilizada para verificar acurácia durante o treinamento.
#
# Com a implementação completa, executando o código abaixo, você deve ser capaz de obter o valor da função de custo próximo a 0.2.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=0.1,
            num_iters=300, verbose=False)

print 'Loss de treinamento: ', stats['loss_history'][-1]

# plotagem dos valores de custo durante o treinamento
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# W1: (4L, 10L)
# b1: (10L,)
# W2: (10L, 15L)
# b2: (15L,)
# W3: (15L, 3L)
# b3: (3L,)
# Loss de treinamento:  0.270682190091

# %% [markdown]
# # Carregando o CIFAR-10
# Com sua implementação completa (e correta), podemos carregar os dados do CIFAR-10 e usá-los para treinar um modelo de rede neuralem dados reais.

# %%
from rncvc.data_utils import load_CIFAR10, save_model, load_model

def get_CIFAR10_data():
    """
    Carregando o CIFAR-10 e efetuando pré-processamento para preparar os dados
    para entrada na Rede Neural.     
    """
    # Carrega o CIFAR-10
    cifar10_dir = 'rncvc/datasets/cifar-10-batches-py'    
    X_train, y_train, X_valid, y_valid = load_CIFAR10(cifar10_dir)   

    # Normalizacao dos dados: subtracao da imagem media
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_valid -= mean_image
    
    print X_train.shape
    print X_valid.shape
    
    # Imagens para linhas 
    X_train = X_train.reshape(X_train.shape[0], -1)
    X_valid = X_valid.reshape(X_valid.shape[0], -1)    

    return X_train, y_train, X_valid, y_valid


# Utiliza a funcao acima pra carregar os dados.
X_train, y_train, X_valid, y_valid = get_CIFAR10_data()
print 'Shape dados treinamento: ', X_train.shape
print 'Shape das classes (treinamento): ', y_train.shape
print 'Shape dados validacao: ', X_valid.shape
print 'Shape das classes (validacao): ', y_valid.shape
# Out:
# (40000L, 32L, 32L, 3L)
# (10000L, 32L, 32L, 3L)
# Shape dados treinamento:  (40000L, 3072L)
# Shape das classes (treinamento):  (40000L,)
# Shape dados validacao:  (10000L, 3072L)
# Shape das classes (validacao):  (10000L,)

# %% [markdown]
# # Treinando a Rede no CIFAR-10
# Para treinar a rede use SGD com momentum. Salve o melhor modelo com a função data_utils.save_model().

# %%
input_size = 32 * 32 * 3
hidden_size = 350
hidden_size2 = 350
num_classes = 15
net = NeuralNet3L(input_size, hidden_size, hidden_size2, num_classes)

# Treina a rede
#stats = net.train(X_train, y_train, X_valid, y_valid,
#            num_iters=1000, batch_size=200,
#            learning_rate=1e-2, learning_rate_decay=0.95,
#            reg=0.5, verbose=True)

stats = net.trainMarcelo(X_train, y_train, X_valid, y_valid,
                                    epochs=1000,
                                    batch_size=200,
                                    learning_rate=5e-3, 
                                    learning_rate_decay=0.95,
                                    reg=0.5, 
                                    verbose=True, 
                                    earlyStopping=15,
                                    optimizer="AdaGrad",
                                    dropout=0.5)


# Efetua predicao no conjunto de validacao
val_acc = (net.predict(X_valid) == y_valid).mean()
print 'Acuracia de validacao: ', val_acc

# Salva o modelo da rede treinada
model_path = 'model3L.pickle'
save_model(model_path, net.params)
# Out:
# W1: (3072L, 350L)
# b1: (350L,)
# W2: (350L, 350L)
# b2: (350L,)
# W3: (350L, 15L)
# b3: (15L,)
# Epoch 0 -> loss 2.196199 acc 0.305000 val_loss 2.204158 val_acc 0.265600  LossVal LossTrain AccVal
# Epoch 1 -> loss 2.142283 acc 0.365000 val_loss 2.108067 val_acc 0.311800  LossVal LossTrain AccVal
# Epoch 2 -> loss 2.103995 acc 0.350000 val_loss 2.093711 val_acc 0.302300  LossVal LossTrain
# Epoch 3 -> loss 2.089981 acc 0.375000 val_loss 2.052337 val_acc 0.320100  LossVal LossTrain AccVal
# Epoch 4 -> loss 2.032221 acc 0.395000 val_loss 2.060641 val_acc 0.317900  LossTrain
# Epoch 5 -> loss 2.002218 acc 0.340000 val_loss 2.024108 val_acc 0.335300  LossVal LossTrain AccVal
# Epoch 6 -> loss 2.078957 acc 0.400000 val_loss 2.053589 val_acc 0.319500
# Epoch 7 -> loss 1.978624 acc 0.435000 val_loss 2.015057 val_acc 0.338200  LossVal LossTrain AccVal
# Epoch 8 -> loss 2.031130 acc 0.410000 val_loss 2.020560 val_acc 0.324900
# Epoch 9 -> loss 2.090332 acc 0.330000 val_loss 2.019762 val_acc 0.323100
# Epoch 10 -> loss 2.207732 acc 0.315000 val_loss 2.023483 val_acc 0.324700
# Epoch 11 -> loss 2.003322 acc 0.415000 val_loss 1.983370 val_acc 0.344100  LossVal AccVal
# Epoch 12 -> loss 1.969493 acc 0.360000 val_loss 1.978092 val_acc 0.343500  LossVal LossTrain
# Epoch 13 -> loss 2.048565 acc 0.385000 val_loss 2.006799 val_acc 0.325300
# Epoch 14 -> loss 1.914198 acc 0.385000 val_loss 1.968432 val_acc 0.346300  LossVal LossTrain AccVal
# Epoch 15 -> loss 2.003613 acc 0.400000 val_loss 1.972351 val_acc 0.351000  AccVal
# Epoch 16 -> loss 2.027800 acc 0.425000 val_loss 1.971178 val_acc 0.353100  AccVal
# Epoch 17 -> loss 1.960105 acc 0.430000 val_loss 1.964739 val_acc 0.355400  LossVal AccVal
# Epoch 18 -> loss 2.103727 acc 0.380000 val_loss 2.032956 val_acc 0.335100
# Epoch 19 -> loss 1.976752 acc 0.380000 val_loss 1.947076 val_acc 0.353100  LossVal
# Epoch 20 -> loss 1.994176 acc 0.435000 val_loss 1.946936 val_acc 0.360700  LossVal AccVal
# Epoch 21 -> loss 1.931277 acc 0.420000 val_loss 1.944730 val_acc 0.357600  LossVal
# Epoch 22 -> loss 1.928284 acc 0.400000 val_loss 1.950429 val_acc 0.346700
# Epoch 23 -> loss 1.914195 acc 0.460000 val_loss 1.942488 val_acc 0.359800  LossVal LossTrain
# Epoch 24 -> loss 1.994642 acc 0.415000 val_loss 1.937783 val_acc 0.362300  LossVal AccVal
# Epoch 25 -> loss 2.046260 acc 0.405000 val_loss 1.944494 val_acc 0.360600
# Epoch 26 -> loss 1.927245 acc 0.420000 val_loss 1.935636 val_acc 0.362800  LossVal AccVal
# Epoch 27 -> loss 1.902913 acc 0.425000 val_loss 1.947489 val_acc 0.356900  LossTrain
# Epoch 28 -> loss 1.922247 acc 0.415000 val_loss 1.930355 val_acc 0.366800  LossVal AccVal
# Epoch 29 -> loss 1.918542 acc 0.420000 val_loss 1.930364 val_acc 0.364600
# Epoch 30 -> loss 1.950075 acc 0.425000 val_loss 1.930836 val_acc 0.361500
# Epoch 31 -> loss 1.873294 acc 0.430000 val_loss 1.942484 val_acc 0.356900  LossTrain
# Epoch 32 -> loss 2.008294 acc 0.430000 val_loss 1.925653 val_acc 0.363000  LossVal
# Epoch 33 -> loss 1.880807 acc 0.465000 val_loss 1.928229 val_acc 0.367200  AccVal
# Epoch 34 -> loss 1.924711 acc 0.415000 val_loss 1.922305 val_acc 0.372000  LossVal AccVal
# Epoch 35 -> loss 2.019526 acc 0.415000 val_loss 1.926215 val_acc 0.366500
# Epoch 36 -> loss 1.921607 acc 0.425000 val_loss 1.920869 val_acc 0.374700  LossVal AccVal
# Epoch 37 -> loss 1.913720 acc 0.410000 val_loss 1.924597 val_acc 0.367100
# Epoch 38 -> loss 1.953706 acc 0.400000 val_loss 1.928249 val_acc 0.366500
# Epoch 39 -> loss 1.933840 acc 0.395000 val_loss 1.936479 val_acc 0.360200
# Epoch 40 -> loss 1.978797 acc 0.370000 val_loss 1.923995 val_acc 0.374900  AccVal
# Epoch 41 -> loss 1.969576 acc 0.400000 val_loss 1.912888 val_acc 0.377900  LossVal AccVal
# Epoch 42 -> loss 1.977206 acc 0.375000 val_loss 1.916511 val_acc 0.378800  AccVal
# Epoch 43 -> loss 1.913869 acc 0.405000 val_loss 1.919804 val_acc 0.370200
# Epoch 44 -> loss 1.981062 acc 0.430000 val_loss 1.908049 val_acc 0.376700  LossVal
# Epoch 45 -> loss 1.917575 acc 0.410000 val_loss 1.915355 val_acc 0.369800
# Epoch 46 -> loss 1.948032 acc 0.430000 val_loss 1.918346 val_acc 0.378000
# Epoch 47 -> loss 1.955016 acc 0.360000 val_loss 1.910671 val_acc 0.379900  AccVal
# Epoch 48 -> loss 1.905291 acc 0.390000 val_loss 1.903243 val_acc 0.382600  LossVal AccVal
# Epoch 49 -> loss 1.830024 acc 0.415000 val_loss 1.910562 val_acc 0.373900  LossTrain
# Epoch 50 -> loss 1.921082 acc 0.375000 val_loss 1.908513 val_acc 0.374900
# Epoch 51 -> loss 2.042827 acc 0.355000 val_loss 1.909359 val_acc 0.372700
# Epoch 52 -> loss 1.819068 acc 0.460000 val_loss 1.912411 val_acc 0.374200  LossTrain
# Epoch 53 -> loss 2.028689 acc 0.445000 val_loss 1.911468 val_acc 0.370200
# Epoch 54 -> loss 1.922407 acc 0.405000 val_loss 1.899939 val_acc 0.386000  LossVal AccVal
# Epoch 55 -> loss 1.983825 acc 0.380000 val_loss 1.900391 val_acc 0.384600
# Epoch 56 -> loss 1.897468 acc 0.420000 val_loss 1.901308 val_acc 0.377300
# Epoch 57 -> loss 1.991370 acc 0.390000 val_loss 1.899929 val_acc 0.385600  LossVal
# Epoch 58 -> loss 1.946983 acc 0.450000 val_loss 1.904815 val_acc 0.376300
# Epoch 59 -> loss 1.969867 acc 0.425000 val_loss 1.897359 val_acc 0.385900  LossVal
# Epoch 60 -> loss 1.854399 acc 0.455000 val_loss 1.897718 val_acc 0.380400
# Epoch 61 -> loss 1.918006 acc 0.415000 val_loss 1.896466 val_acc 0.381100  LossVal
# Epoch 62 -> loss 1.953365 acc 0.390000 val_loss 1.892946 val_acc 0.384600  LossVal
# Epoch 63 -> loss 1.918701 acc 0.410000 val_loss 1.897976 val_acc 0.382200
# Epoch 64 -> loss 1.903017 acc 0.455000 val_loss 1.893705 val_acc 0.378600
# Epoch 65 -> loss 1.950968 acc 0.360000 val_loss 1.893017 val_acc 0.386600  AccVal
# Epoch 66 -> loss 1.933733 acc 0.365000 val_loss 1.890922 val_acc 0.385900  LossVal
# Epoch 67 -> loss 1.966104 acc 0.360000 val_loss 1.891885 val_acc 0.385100
# Epoch 68 -> loss 1.929411 acc 0.370000 val_loss 1.896862 val_acc 0.383700
# Epoch 69 -> loss 1.967416 acc 0.430000 val_loss 1.890320 val_acc 0.384700  LossVal
# Epoch 70 -> loss 1.897343 acc 0.475000 val_loss 1.892301 val_acc 0.384100
# Epoch 71 -> loss 1.883716 acc 0.385000 val_loss 1.889008 val_acc 0.386100  LossVal
# Epoch 72 -> loss 1.860744 acc 0.485000 val_loss 1.887223 val_acc 0.386200  LossVal
# Epoch 73 -> loss 1.921195 acc 0.430000 val_loss 1.886042 val_acc 0.388200  LossVal AccVal
# Epoch 74 -> loss 1.937591 acc 0.450000 val_loss 1.888904 val_acc 0.390800  AccVal
# Epoch 75 -> loss 1.945535 acc 0.400000 val_loss 1.885069 val_acc 0.388700  LossVal
# Epoch 76 -> loss 1.901787 acc 0.465000 val_loss 1.886668 val_acc 0.388800
# Epoch 77 -> loss 1.861735 acc 0.390000 val_loss 1.886773 val_acc 0.387200
# Epoch 78 -> loss 1.931590 acc 0.400000 val_loss 1.885520 val_acc 0.387900
# Epoch 79 -> loss 1.815981 acc 0.485000 val_loss 1.884958 val_acc 0.390300  LossVal LossTrain
# Epoch 80 -> loss 1.984096 acc 0.345000 val_loss 1.887909 val_acc 0.388600
# Epoch 81 -> loss 1.951540 acc 0.390000 val_loss 1.884892 val_acc 0.390500  LossVal
# Epoch 82 -> loss 1.888362 acc 0.375000 val_loss 1.884631 val_acc 0.390700  LossVal
# Epoch 83 -> loss 1.939842 acc 0.360000 val_loss 1.883231 val_acc 0.393700  LossVal AccVal
# Epoch 84 -> loss 1.913908 acc 0.405000 val_loss 1.884291 val_acc 0.389300
# Epoch 85 -> loss 2.003786 acc 0.355000 val_loss 1.884616 val_acc 0.390000
# Epoch 86 -> loss 1.854423 acc 0.445000 val_loss 1.881603 val_acc 0.393300  LossVal
# Epoch 87 -> loss 1.903525 acc 0.385000 val_loss 1.881648 val_acc 0.392000
# Epoch 88 -> loss 1.839049 acc 0.455000 val_loss 1.882457 val_acc 0.390800
# Epoch 89 -> loss 1.969398 acc 0.375000 val_loss 1.881099 val_acc 0.389900  LossVal
# Epoch 90 -> loss 1.911635 acc 0.370000 val_loss 1.880482 val_acc 0.394200  LossVal AccVal
# Epoch 91 -> loss 1.905314 acc 0.395000 val_loss 1.880128 val_acc 0.392100  LossVal
# Epoch 92 -> loss 1.910018 acc 0.425000 val_loss 1.879599 val_acc 0.393500  LossVal
# Epoch 93 -> loss 1.901310 acc 0.435000 val_loss 1.879557 val_acc 0.391700  LossVal
# Epoch 94 -> loss 1.956408 acc 0.360000 val_loss 1.880499 val_acc 0.393500
# Epoch 95 -> loss 1.911657 acc 0.410000 val_loss 1.880283 val_acc 0.390900
# Epoch 96 -> loss 1.833465 acc 0.420000 val_loss 1.878281 val_acc 0.394500  LossVal AccVal
# Epoch 97 -> loss 1.836125 acc 0.445000 val_loss 1.879672 val_acc 0.391800
# Epoch 98 -> loss 1.753102 acc 0.480000 val_loss 1.878839 val_acc 0.393300  LossTrain
# Epoch 99 -> loss 1.876680 acc 0.400000 val_loss 1.877890 val_acc 0.397000  LossVal AccVal
# Epoch 100 -> loss 1.847215 acc 0.410000 val_loss 1.879091 val_acc 0.394100
# Epoch 101 -> loss 1.874347 acc 0.390000 val_loss 1.878195 val_acc 0.394900
# Epoch 102 -> loss 2.020123 acc 0.355000 val_loss 1.879298 val_acc 0.397000
# Epoch 103 -> loss 1.927296 acc 0.415000 val_loss 1.876998 val_acc 0.394300  LossVal
# Epoch 104 -> loss 1.947796 acc 0.365000 val_loss 1.876530 val_acc 0.395700  LossVal
# Epoch 105 -> loss 1.945959 acc 0.395000 val_loss 1.875836 val_acc 0.394000  LossVal
# Epoch 106 -> loss 1.879863 acc 0.440000 val_loss 1.877935 val_acc 0.397200  AccVal
# Epoch 107 -> loss 1.805851 acc 0.415000 val_loss 1.877307 val_acc 0.393400
# Epoch 108 -> loss 1.765494 acc 0.475000 val_loss 1.877671 val_acc 0.395000
# Epoch 109 -> loss 1.926406 acc 0.400000 val_loss 1.877214 val_acc 0.394400
# Epoch 110 -> loss 1.871637 acc 0.385000 val_loss 1.876745 val_acc 0.393900
# Epoch 111 -> loss 1.825813 acc 0.480000 val_loss 1.875660 val_acc 0.396900  LossVal
# Epoch 112 -> loss 1.971714 acc 0.315000 val_loss 1.875573 val_acc 0.396400  LossVal
# Epoch 113 -> loss 1.854461 acc 0.385000 val_loss 1.877073 val_acc 0.395500
# Epoch 114 -> loss 1.844339 acc 0.445000 val_loss 1.876009 val_acc 0.396900
# Epoch 115 -> loss 1.793326 acc 0.450000 val_loss 1.874315 val_acc 0.397600  LossVal AccVal
# Epoch 116 -> loss 1.879475 acc 0.460000 val_loss 1.875133 val_acc 0.396300
# Epoch 117 -> loss 1.941317 acc 0.440000 val_loss 1.874140 val_acc 0.397200  LossVal
# Epoch 118 -> loss 1.839621 acc 0.445000 val_loss 1.874829 val_acc 0.395400
# Epoch 119 -> loss 1.887988 acc 0.405000 val_loss 1.873066 val_acc 0.394400  LossVal
# Epoch 120 -> loss 1.901111 acc 0.380000 val_loss 1.874390 val_acc 0.396300
# Epoch 121 -> loss 1.874804 acc 0.445000 val_loss 1.873720 val_acc 0.395200
# Epoch 122 -> loss 1.885566 acc 0.405000 val_loss 1.873652 val_acc 0.397000
# Epoch 123 -> loss 1.959052 acc 0.410000 val_loss 1.873804 val_acc 0.398900  AccVal
# Epoch 124 -> loss 1.869491 acc 0.395000 val_loss 1.873761 val_acc 0.397600
# Epoch 125 -> loss 1.971582 acc 0.360000 val_loss 1.874004 val_acc 0.396800
# Epoch 126 -> loss 2.018450 acc 0.345000 val_loss 1.873485 val_acc 0.399600  AccVal
# Epoch 127 -> loss 1.802933 acc 0.430000 val_loss 1.873888 val_acc 0.398900
# Epoch 128 -> loss 1.845852 acc 0.400000 val_loss 1.872540 val_acc 0.398400  LossVal
# Epoch 129 -> loss 1.948410 acc 0.390000 val_loss 1.872834 val_acc 0.397200
# Epoch 130 -> loss 1.955396 acc 0.375000 val_loss 1.872426 val_acc 0.398900  LossVal
# Epoch 131 -> loss 1.895277 acc 0.405000 val_loss 1.873122 val_acc 0.397400
# Epoch 132 -> loss 1.802614 acc 0.470000 val_loss 1.872685 val_acc 0.396700
# Epoch 133 -> loss 1.817179 acc 0.445000 val_loss 1.872391 val_acc 0.396800  LossVal
# Epoch 134 -> loss 1.898139 acc 0.400000 val_loss 1.872103 val_acc 0.396400  LossVal
# Epoch 135 -> loss 1.885323 acc 0.405000 val_loss 1.872130 val_acc 0.398000
# Epoch 136 -> loss 1.775059 acc 0.485000 val_loss 1.872111 val_acc 0.397400
# Epoch 137 -> loss 1.845910 acc 0.420000 val_loss 1.872399 val_acc 0.397200
# Epoch 138 -> loss 1.869641 acc 0.425000 val_loss 1.871612 val_acc 0.396900  LossVal
# Epoch 139 -> loss 1.853394 acc 0.370000 val_loss 1.871588 val_acc 0.398500  LossVal
# Epoch 140 -> loss 1.778350 acc 0.480000 val_loss 1.871990 val_acc 0.394600
# Epoch 141 -> loss 1.885208 acc 0.360000 val_loss 1.871718 val_acc 0.398500
# Epoch 142 -> loss 1.829448 acc 0.430000 val_loss 1.871813 val_acc 0.397700
# Epoch 143 -> loss 2.000868 acc 0.335000 val_loss 1.871882 val_acc 0.398500
# Epoch 144 -> loss 1.893485 acc 0.390000 val_loss 1.871538 val_acc 0.399500  LossVal
# Epoch 145 -> loss 1.891464 acc 0.470000 val_loss 1.871878 val_acc 0.397100
# Epoch 146 -> loss 1.770900 acc 0.520000 val_loss 1.871780 val_acc 0.398800
# Epoch 147 -> loss 1.791364 acc 0.440000 val_loss 1.871295 val_acc 0.399600  LossVal
# Epoch 148 -> loss 1.851160 acc 0.425000 val_loss 1.871543 val_acc 0.397900
# Epoch 149 -> loss 1.917625 acc 0.385000 val_loss 1.871507 val_acc 0.398500
# Epoch 150 -> loss 1.847367 acc 0.445000 val_loss 1.871546 val_acc 0.397800
# Epoch 151 -> loss 1.937721 acc 0.365000 val_loss 1.871515 val_acc 0.400100  AccVal
# Epoch 152 -> loss 1.908234 acc 0.430000 val_loss 1.871079 val_acc 0.399200  LossVal
# Epoch 153 -> loss 1.846853 acc 0.440000 val_loss 1.871214 val_acc 0.398600
# Epoch 154 -> loss 1.890862 acc 0.390000 val_loss 1.871342 val_acc 0.398900
# Epoch 155 -> loss 1.833465 acc 0.400000 val_loss 1.870910 val_acc 0.397600  LossVal
# Epoch 156 -> loss 1.806312 acc 0.460000 val_loss 1.871028 val_acc 0.399000
# Epoch 157 -> loss 1.928455 acc 0.345000 val_loss 1.870984 val_acc 0.398400
# Epoch 158 -> loss 1.858463 acc 0.435000 val_loss 1.870824 val_acc 0.398300  LossVal
# Epoch 159 -> loss 1.817744 acc 0.420000 val_loss 1.871026 val_acc 0.399000
# Epoch 160 -> loss 1.883084 acc 0.400000 val_loss 1.870773 val_acc 0.398500  LossVal
# Epoch 161 -> loss 1.885335 acc 0.410000 val_loss 1.870832 val_acc 0.398600
# Epoch 162 -> loss 1.861836 acc 0.395000 val_loss 1.870920 val_acc 0.399100
# Epoch 163 -> loss 1.910393 acc 0.350000 val_loss 1.870918 val_acc 0.399600
# Epoch 164 -> loss 1.892521 acc 0.435000 val_loss 1.871150 val_acc 0.399200
# Epoch 165 -> loss 1.903280 acc 0.410000 val_loss 1.870857 val_acc 0.399400
# Epoch 166 -> loss 1.860565 acc 0.425000 val_loss 1.870857 val_acc 0.399800
# Epoch 167 -> loss 1.847736 acc 0.435000 val_loss 1.870861 val_acc 0.399000
# Epoch 168 -> loss 1.887885 acc 0.385000 val_loss 1.870681 val_acc 0.398300  LossVal
# Epoch 169 -> loss 1.838368 acc 0.405000 val_loss 1.870784 val_acc 0.399500
# Epoch 170 -> loss 1.942955 acc 0.405000 val_loss 1.870853 val_acc 0.398900
# Epoch 171 -> loss 1.909403 acc 0.390000 val_loss 1.870815 val_acc 0.398800
# Epoch 172 -> loss 1.796527 acc 0.425000 val_loss 1.870754 val_acc 0.399300
# Epoch 173 -> loss 1.856470 acc 0.415000 val_loss 1.870759 val_acc 0.399400
# Epoch 174 -> loss 1.909453 acc 0.435000 val_loss 1.870803 val_acc 0.399200
# Epoch 175 -> loss 1.812850 acc 0.425000 val_loss 1.870790 val_acc 0.398700
# Epoch 176 -> loss 1.857450 acc 0.385000 val_loss 1.870705 val_acc 0.399100
# Epoch 177 -> loss 1.808366 acc 0.415000 val_loss 1.870742 val_acc 0.398500
# Epoch 178 -> loss 1.822499 acc 0.390000 val_loss 1.870740 val_acc 0.398600
# Epoch 179 -> loss 1.825865 acc 0.470000 val_loss 1.870710 val_acc 0.398600
# Epoch 180 -> loss 1.908902 acc 0.340000 val_loss 1.870675 val_acc 0.398600  LossVal
# Epoch 181 -> loss 1.815323 acc 0.435000 val_loss 1.870597 val_acc 0.398900  LossVal
# Epoch 182 -> loss 1.843183 acc 0.445000 val_loss 1.870539 val_acc 0.398900  LossVal
# Epoch 183 -> loss 1.870285 acc 0.425000 val_loss 1.870529 val_acc 0.398600  LossVal
# Epoch 184 -> loss 1.886741 acc 0.430000 val_loss 1.870587 val_acc 0.399400
# Epoch 185 -> loss 1.948187 acc 0.355000 val_loss 1.870606 val_acc 0.399200
# Epoch 186 -> loss 1.856311 acc 0.455000 val_loss 1.870590 val_acc 0.398900
# Epoch 187 -> loss 1.937263 acc 0.410000 val_loss 1.870590 val_acc 0.399200
# Epoch 188 -> loss 1.827066 acc 0.430000 val_loss 1.870575 val_acc 0.399200
# Epoch 189 -> loss 1.840371 acc 0.430000 val_loss 1.870559 val_acc 0.399300
# Epoch 190 -> loss 1.931929 acc 0.395000 val_loss 1.870561 val_acc 0.399400
# Epoch 191 -> loss 1.872313 acc 0.410000 val_loss 1.870554 val_acc 0.399600
# Epoch 192 -> loss 1.783797 acc 0.445000 val_loss 1.870541 val_acc 0.399400
# Epoch 193 -> loss 1.837070 acc 0.440000 val_loss 1.870495 val_acc 0.400000  LossVal
# Epoch 194 -> loss 1.861939 acc 0.425000 val_loss 1.870515 val_acc 0.399700
# Epoch 195 -> loss 1.805621 acc 0.415000 val_loss 1.870505 val_acc 0.399100
# Epoch 196 -> loss 1.882958 acc 0.380000 val_loss 1.870545 val_acc 0.399400
# Epoch 197 -> loss 1.857653 acc 0.420000 val_loss 1.870536 val_acc 0.399400
# Epoch 198 -> loss 1.804352 acc 0.440000 val_loss 1.870492 val_acc 0.399800  LossVal
# Epoch 199 -> loss 1.874054 acc 0.380000 val_loss 1.870494 val_acc 0.399500
# Epoch 200 -> loss 1.860645 acc 0.380000 val_loss 1.870516 val_acc 0.399300
# Epoch 201 -> loss 1.837626 acc 0.415000 val_loss 1.870513 val_acc 0.399700
# Epoch 202 -> loss 1.851671 acc 0.475000 val_loss 1.870511 val_acc 0.399800
# Epoch 203 -> loss 1.879453 acc 0.405000 val_loss 1.870493 val_acc 0.399900
# Epoch 204 -> loss 1.945723 acc 0.385000 val_loss 1.870487 val_acc 0.399200  LossVal
# Epoch 205 -> loss 1.784379 acc 0.405000 val_loss 1.870490 val_acc 0.399300
# Epoch 206 -> loss 1.853358 acc 0.420000 val_loss 1.870519 val_acc 0.399700
# Epoch 207 -> loss 1.819534 acc 0.435000 val_loss 1.870542 val_acc 0.399700
# Epoch 208 -> loss 1.918958 acc 0.420000 val_loss 1.870515 val_acc 0.399500
# Epoch 209 -> loss 1.882815 acc 0.390000 val_loss 1.870519 val_acc 0.399600
# Epoch 210 -> loss 1.850910 acc 0.410000 val_loss 1.870494 val_acc 0.399300
# Epoch 211 -> loss 1.866432 acc 0.410000 val_loss 1.870495 val_acc 0.399300
# Epoch 212 -> loss 1.958769 acc 0.345000 val_loss 1.870502 val_acc 0.399300
# Epoch 213 -> loss 1.872828 acc 0.435000 val_loss 1.870493 val_acc 0.399500
# Epoch 214 -> loss 1.913395 acc 0.340000 val_loss 1.870494 val_acc 0.399300
# Epoch 215 -> loss 1.890331 acc 0.395000 val_loss 1.870512 val_acc 0.399400
# Epoch 216 -> loss 1.902217 acc 0.390000 val_loss 1.870515 val_acc 0.399300
# Epoch 217 -> loss 1.942778 acc 0.355000 val_loss 1.870508 val_acc 0.399400
# Epoch 218 -> loss 1.854968 acc 0.480000 val_loss 1.870499 val_acc 0.399500
# Epoch 219 -> loss 1.860079 acc 0.375000 val_loss 1.870489 val_acc 0.399200
# Acuracia de validacao:  0.3992
# True

# %% [markdown]
# # Acompanhando o treinamento
#
# Com os hiperparâmetros definidos anteriormente você provavelmente não obterá bons resultados: a acurácia não deve passar de 30%.
#
# Uma estratégia para entender o que não está bom durante o treinamento é plotar os valores da função de custo e acurácia durante o treinamento.
#
# Outra estratégia é visualizar os pesos aprendidos na primeira camada durante o processo de otimização. Normalmente, redes treinadas em dados visuais apresentam padrões estruturais visíveis na primeira camada.

# %%
# Plota a função de custo e acurácia
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.show()

# %%
from rncvc.vis_utils import visualize_grid

# Visualiza os pesos da rede

def show_net_weights(net):
    W1 = net.params['W1']
    W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')
    plt.show()
    
#def show_net_weights2(net):
#    W1 = net.params['W1']
#    W2 = net.params['W2']
#    print W1.shape
#    print W1.reshape(32, 32, 3, -1).shape
#    print W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2).shape
    
#    print W2.shape
#    print W2.transpose(1,0).shape
#    print W2.transpose(1,0).reshape(50,10,10,-3).shape
    
#    W2 = W2.transpose(1,0).reshape(50,10,10)
#    plt.imshow(W2[10])
    #plt.imshow(visualize_grid(W2, padding=3).astype('uint8'))
#    plt.gca().axis('off')
#    plt.show()    

show_net_weights(net)
#show_net_weights2(net)

# %% [markdown]
# # Desafio RNCVC 2017
#
# **Dicas**
# * Tune os hiperparâmetros (taxa de aprendizado, número de neurônios, etc).
# * Regularize o modelo: teste o uso de Regularização L2 e Dropout.
# * Use validação cruzada para achar os melhores hiperparâmetros.
# * Utilize um esquema mais sofisticado de atualização dos pesos (ex: SGD + Momentum, Nesterov, Adadelta, Adam, RMSProp).
# * Teste funções de ativação (ex: ELU, Leaky ReLU) e Batch Normalization.
# * Salve o melhor modelo obtido usando data_utils.save_model() e data_utils.load_model() para abrir.
# * O campeão do ano passado conseguiu 62% de acurácia!

# %% [markdown]
# Para o desafio: é <b>fundamental</b> que o trecho abaixo seja executado sem problemas.

# %%
# Assuma que o modelo são os pesos serializados em disco usando data_utils.save_model()

input_size = 32 * 32 * 3
hidden_size = 350
hidden_size2 = 350
num_classes = 10
net = NeuralNet3L(input_size, hidden_size,hidden_size2, num_classes)

best_model = 'model3L.pickle'
model = load_model(best_model)
net.params = model

# Retorna um vetor de predição (N x 1), onde N é o número de instâncias
# As classes retornadas aqui devem ser inteiros: [0, 1, 2, ..., C]
# Assuma que X_teste e uma matriz de instancias (N_test, D) 
# Voce nao tera o X_teste oficial, use outro conjunto para validar.

train_predicted = net.predict(X_train)
valid_predicted = net.predict(X_valid)
# Out:
# W1: (3072L, 350L)
# b1: (350L,)
# W2: (350L, 350L)
# b2: (350L,)
# W3: (350L, 10L)
# b3: (10L,)

# %% [markdown]
# Reporte abaixo os valores de acurácia no treino e validação do modelo enviado para o desafio.

# %%
# Treino: 00.00%
# Validacao: 00.00%

print 'Treino: ', (train_predicted == y_train).mean(), "%"
print 'Validacao: ', (valid_predicted == y_valid).mean(), "%"
# Out:
# Treino:  0.41085 %
# Validacao:  0.3992 %
